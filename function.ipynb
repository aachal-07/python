# %% [markdown]
# FUNCTIONS IN PYTHON

# %%
def funtion_name():
    # apna code likhna 
    pass
funtion_name()

# %%
def temp():
    print("hello aachal")

# %%
temp()
# Out:
# hello aachal

# %%
def Demo(name):
    print(f"hello{name} aachal")

# %%
Demo(name = "mam")
# Out:
# hellomam aachal

# %%
def mul_table(num1 , num2):
    print(num1*num2)

# %%
mul_table(num1 = 2 , num2 = 3)
# Out:
# 6

# %%
def add(a , b ):
    return a+b

# %%
result =add(a = 2 , b = 3)

# %%
print(result)
# Out:
# 5

# %%
def greet(name= "Guest"):   
    print(f"hello {name}")
greet()
# Out:
# hello Guest

# %%
greet(name = "Ritik")
greet(name = "Ritik")

greet(name = "Ritik")
greet(name = "Ritik")
greet(name = "Ritik")
greet(name = "Ritik")
greet(name = "Ritik")
greet(name = "Ritik")
greet(name = "Ritik")
# Out:
# hello Ritik
# hello Ritik
# hello Ritik
# hello Ritik
# hello Ritik
# hello Ritik
# hello Ritik
# hello Ritik
# hello Ritik

# %% [markdown]
# LAMBDA FUNCTIONS

# %%
# lambda args: expression

add =lambda a,b : a+b
print(add(2,3))
# Out:
# 5

# %%
print(add(2,3))
print(add(2,3))
print(add(2,3))
print(add(2,8))
print(add(2,5))
print(add(2,3))
print(add(2,99))
# Out:
# 5
# 5
# 5
# 10
# 7
# 5
# 101

# %%
square =lambda a : a*a
print(square(2))
# Out:
# 4

# %%
print(square(2))
print(square(7))
print(square(4))
print(square(5))
print(square(2))
# Out:
# 4
# 49
# 16
# 25
# 4
