# %% [markdown]
# OPERATING SYSTEM

# %%
print("os module")
import os
# Out:
# os module

# %%
file=os.getcwd()   # current working directory
print("current working directory",file)
# Out:
# current working directory c:\Users\DELL\OneDrive\Desktop\DSwithML\python\os

# %%
file=os.listdir()
print("total list os current directory:",file)
# Out:
# total list os current directory: ['os.ipynb']

# %%
os.mkdir("New_folder")
print("file created")
# Out:
# file created

# %%
file=os.listdir()
print("total list os current directory:",file)
# Out:
# total list os current directory: ['New_folder', 'os.ipynb']

# %%
os.rename("New_folder","Datascience")
print("folder rename successfully")
# Out:
# folder rename successfully

# %%
file=os.listdir()
print("total list os current directory:",file)
# Out:
# total list os current directory: ['Datascience', 'os.ipynb']

# %%
os.rmdir("Datascience")
print("folder removed")
# Out:
# folder removed

# %%
file =os.listdir()
print("total list os current directory:-",file)
# Out:
# total list os current directory:- ['os.ipynb']

# %%
path=r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python\os"

# %%
path=os.environ.get(path)
print("path exists:-",path)
# Out:
# path exists:- None

# %%
os.system("e:\Desktop\python")
# Out:
# 1

# %%
os.system("dir")
# Out:
# 0

# %%
os.listdir(r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python\os")
# Out:
# ['os.ipynb']

# %%
os.path.isfile(r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python\filehandling.ipynb")
# Out:
# False

# %%
os.path.isdir(r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python")
# Out:
# True

# %%
os.path.isdir(r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python\numpy")
# Out:
# True

# %%
size=os.path.getsize(r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python\os\os.ipynb")
print("size of file (in byte):-",size)
# Out:
# size of file (in byte):- 8165

# %%
print("before dir ",os.getcwd())
os.chdir(r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python\numpy")
print("after dir ",os.getcwd())
# Out:
# before dir  c:\Users\DELL\OneDrive\Desktop\DSwithML\python\os
# after dir  C:\Users\DELL\OneDrive\Desktop\DSwithML\python\numpy

# %%
path1=r"C:\Users\DELL\OneDrive\Desktop\DSwithML\python"
path2=r"numpy"
complete_path=os.path.join(path1,path2)
print("your complete path:-",complete_path)
print("your list:-",os.listdir(complete_path))
# Out:
# your complete path:- C:\Users\DELL\OneDrive\Desktop\DSwithML\python\numpy
# your list:- ['basic.ipynb']
