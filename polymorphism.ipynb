# %%
lst = [1,2,3,4,5]
print(lst)
print(len(lst))
# Out:
# [1, 2, 3, 4, 5]
# 5

# %%
tup = (1,2,3,4,5)
print(tup)
# Out:
# (1, 2, 3, 4, 5)

# %%
myset={1,2,3,4,5}
print(myset)
# Out:
# {1, 2, 3, 4, 5}

# %%
def add(a,b, c = 0):
    return a + b + c
print(add(2,3))
print(add(2,3,4))
# Out:
# 5
# 9
